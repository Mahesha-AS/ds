# %%
class School:
    def __init__(self, name):
        self.name = name
        #self.id_num = id_num

        
class Teacher(School):
    def __init__(self, name):
        super(Teacher, self).__init__(name)

    #adding new Teacher
    def accept(self):
        teacher_id=input("Please enter Teacher ID :")
        teacher_doj=input("Please enter Teacher's Date of joining :")
        teacher_dep=input("Please enter Department :")
        
        myfile=open('teachers.txt', 'a+')
        myfile.write(self.name + ',' + teacher_id + ',' + teacher_doj + ',' + teacher_dep + '\n' )
        myfile.close()
        print('Added record of teacher {} successfully. \n' .format(self.name))

        
    #To view Teacher details
    def view(self):
        mylines = [] 
        with open("teachers.txt") as myfile:
            for line in myfile:
                if self.name in line:
                    mylines.append(line)
        print('\n{} records found for {}\n' .format(len(mylines), self.name))
        for element in mylines:
            li=element.split(',')
            print('Teacher_Name: {} \nID: {} \nDOJ: {} \nDepartment: {}' .format(li[0], li[1], li[2], li[3]))
    
    #To delete Teacher record
    def remove(self):
        mylines = []
        output = []
        new_lines = []
        del_line = []
        
        #to check Teacher record exists or not
        with open("teachers.txt") as myfile:
            for line in myfile:
                if self.name in line:
                    mylines.append(line)
                else :
                    output.append(line)
        #if no record found
        if (len(mylines)==0):
            print('\nno records found for {}\n' .format(self.name))
        
        #if 1 record found
        elif (len(mylines)==1):
            f = open("teachers.txt", 'w')
            f.writelines(output)
            f.close()
            print('\nBelow record deleted\n')
            for element in mylines:
                li=element.split(',')
                print('Teacher_Name: {} \nID: {} \nDOJ: {} \nDepartment: {}' .format(li[0], li[1], li[2], li[3]))
        
        #if more than 1 record found
        else :
            print('\n{} records found for {}\n' .format(len(mylines), self.name))
            for element in mylines:
                li=element.split(',')
                print('Teacher_Name: {} \nID: {} \nDOJ: {} \nDepartment: {}' .format(li[0], li[1], li[2], li[3]))
            check_id=int(input('\nPlease enter the specific Teacher ID to delete the teacher {} :' .format(self.name)))
            
            #to delete specific Teacher record
            for element in mylines:
                if (self.name+','+str(check_id)+',') not in element:
                    new_lines.append(element)
                else:
                    del_line.append(element)
            output = output + new_lines
            f = open("teachers.txt", 'w')
            f.writelines(output)
            f.close()
            print('\nBelow record deleted\n')
            for element in del_line:
                li=element.split(',')
                print('Teacher_Name: {} \nID: {} \nDOJ: {} \nDepartment: {}' .format(li[0], li[1], li[2], li[3]))
        
    #To update Teacher details            
    def update(self):
        mylines = []
        output = []
        new_lines = []
        update_line = []
        
        #to check teacher record exists or not
        with open("teachers.txt") as myfile:
            for line in myfile:
                if self.name in line:
                    mylines.append(line)
                else :
                    output.append(line)
        
        #if no record found
        if (len(mylines)==0):
            print('\nno records found for {}\n' .format(self.name))
        
        #if 1 record found
        elif (len(mylines)==1):
            print('\nTeacher details which you selected to update\n')
            for element in mylines:
                li=element.split(',')
                print('Teacher_Name: {} \nID: {} \nDOJ: {} \nDepartment: {}' .format(li[0], li[1], li[2], li[3]))
            
            ch = int(input('\n1. To update Teacher name \n2. To update Date of Joining \n3. To update Department \n'))
            
            #to update Teacher name
            if ch == 1 :
                new_t_name=input('Enter new Teacher name :')
                for element in mylines:
                    li=element.split(',')
                li[0]=new_t_name
                my_string = ','.join(map(str, li))
                new_mylines=list(my_string)
                output = output + new_mylines
                
                f = open("teachers.txt", 'w')
                f.writelines(output)
                f.close()
                
                print('\nUpdated Teacher record details\n')
                print('Teacher_Name: {} \nID: {} \nDOJ: {} \nDepartment: {}' .format(li[0], li[1], li[2], li[3]))                         
            
            #to update Teacher DOJ
            elif ch == 2 :
                new_t_doj=input('Enter Date of Joining :')
                for element in mylines:
                    li=element.split(',')
                li[2]=new_t_doj
                my_string = ','.join(map(str, li))
                new_mylines=list(my_string)
                output = output + new_mylines
                
                f = open("teachers.txt", 'w')
                f.writelines(output)
                f.close()
                
                print('\nUpdated Teacher record details\n')
                print('Teacher_Name: {} \nID: {} \nDOJ: {} \nDepartment: {}' .format(li[0], li[1], li[2], li[3])) 
                
            #to update Teacher Department
            elif ch == 3 :
                new_t_dep=input('Enter new Department :')
                for element in mylines:
                    li=element.split(',')
                li[3]=new_t_dep
                my_string = ','.join(map(str, li))
                new_mylines=list(my_string)
                output = output + new_mylines
                
                f = open("teachers.txt", 'w')
                f.writelines(output)
                f.close()
                
                myfile=open('teachers.txt', 'a+')
                myfile.write('\n' )
                myfile.close()
                
                print('\nUpdated Teacher record details\n')
                print('Teacher_Name: {} \nID: {} \nDOJ: {} \nDepartment: {}' .format(li[0], li[1], li[2], li[3]))                 
                           
        #if more than 1 record found
        else :
            print('\n{} records found for {}\n' .format(len(mylines), self.name))
            for element in mylines:
                li=element.split(',')
                print('Teacher_Name: {} \nID: {} \nDOJ: {} \nDepartment: {}' .format(li[0], li[1], li[2], li[3]))
            check_id=int(input('\nPlease enter the specific Teacher ID to update the teacher {} :' .format(self.name)))
            
            #to update specific Teacher record
            for element in mylines:
                if (self.name+','+str(check_id)+',') not in element:
                    update_line.append(element)
                else:
                    new_lines.append(element)
            output = output + update_line

            ch = int(input('\n1. To update Teacher name \n2. To update Date of Joining \n3. To update Department \n'))
            
            #to update Teacher name
            if ch == 1 :
                new_t_name=input('Enter new Teacher name :')
                for element in new_lines:
                    li=element.split(',')
                li[0]=new_t_name
                my_string = ','.join(map(str, li))
                new_mylines=list(my_string)
                output = output + new_mylines
                
                f = open("teachers.txt", 'w')
                f.writelines(output)
                f.close()
                
                print('\nUpdated Teacher record details\n')
                print('Teacher_Name: {} \nID: {} \nDOJ: {} \nDepartment: {}' .format(li[0], li[1], li[2], li[3]))                         
            
            #to update Teacher DOJ
            elif ch == 2 :
                new_t_doj=input('Enter Date of Joining :')
                for element in new_lines:
                    li=element.split(',')
                li[2]=new_t_doj
                my_string = ','.join(map(str, li))
                new_mylines=list(my_string)
                output = output + new_mylines
                #output= '\n'.join([output, new_mylines])
                
                f = open("teachers.txt", 'w')
                f.writelines(output)
                f.close()
                
                print('\nUpdated Teacher record details\n')
                print('Teacher_Name: {} \nID: {} \nDOJ: {} \nDepartment: {}' .format(li[0], li[1], li[2], li[3])) 
                
            #to update Teacher Department
            elif ch == 3 :
                new_t_dep=input('Enter new Department :')
                for element in new_lines:
                    li=element.split(',')
                li[3]=new_t_dep
                my_string = ','.join(map(str, li))
                new_mylines=list(my_string)
                output = output + new_mylines
                
                f = open("teachers.txt", 'w')
                f.writelines(output)
                f.close()

                myfile=open('teachers.txt', 'a+')
                myfile.write('\n' )
                myfile.close()                
                
                print('\nUpdated teacher record details\n')
                print('Teacher_Name: {} \nID: {} \nDOJ: {} \nDepartment: {}' .format(li[0], li[1], li[2], li[3]))                 
        
        
      
        
class Student(School):
    def __init__(self, name):
        super(Student, self).__init__(name)
        
    #adding new student
    def accept(self):
        student_id=input("Please enter Student ID :")
        student_dob=input("Please enter Date of birth of Student :")
        student_sub=input("Please enter Subject :")
        
        myfile=open('students.txt', 'a+')
        myfile.write(self.name + ',' + student_id + ',' + student_dob + ',' + student_sub + '\n' )
        myfile.close()
        print('Added record of student {} successfully. \n' .format(self.name))

        
    #To view student details
    def view(self):
        mylines = [] 
        with open("students.txt") as myfile:
            for line in myfile:
                if self.name in line:
                    mylines.append(line)
        print('\n{} records found for {}\n' .format(len(mylines), self.name))
        for element in mylines:
            li=element.split(',')
            print('Student_Name: {} \nID: {} \nDOB: {} \nSubject: {}' .format(li[0], li[1], li[2], li[3]))
    
    #To delete student record
    def remove(self):
        mylines = []
        output = []
        new_lines = []
        del_line = []
        
        #to check student record exists or not
        with open("students.txt") as myfile:
            for line in myfile:
                if self.name in line:
                    mylines.append(line)
                else :
                    output.append(line)
        #if no record found
        if (len(mylines)==0):
            print('\nno records found for {}\n' .format(self.name))
        
        #if 1 record found
        elif (len(mylines)==1):
            f = open("students.txt", 'w')
            f.writelines(output)
            f.close()
            print('\nBelow record deleted\n')
            for element in mylines:
                li=element.split(',')
                print('Student_Name: {} \nID: {} \nDOB: {} \nSubject: {}' .format(li[0], li[1], li[2], li[3]))
        
        #if more than 1 record found
        else :
            print('\n{} records found for {}\n' .format(len(mylines), self.name))
            for element in mylines:
                li=element.split(',')
                print('Student_Name: {} \nID: {} \nDOB: {} \nSubject: {}' .format(li[0], li[1], li[2], li[3]))
            check_id=int(input('\nPlease enter the specific Student ID to delete the student {} :' .format(self.name)))
            
            #to delete specific student record
            for element in mylines:
                if (self.name+','+str(check_id)+',') not in element:
                    new_lines.append(element)
                else:
                    del_line.append(element)
            output = output + new_lines
            f = open("students.txt", 'w')
            f.writelines(output)
            f.close()
            print('\nBelow record deleted\n')
            for element in del_line:
                li=element.split(',')
                print('Student_Name: {} \nID: {} \nDOB: {} \nSubject: {}' .format(li[0], li[1], li[2], li[3]))
        
    #To update student details            
    def update(self):
        mylines = []
        output = []
        new_lines = []
        update_line = []
        
        #to check student record exists or not
        with open("students.txt") as myfile:
            for line in myfile:
                if self.name in line:
                    mylines.append(line)
                else :
                    output.append(line)
        
        #if no record found
        if (len(mylines)==0):
            print('\nno records found for {}\n' .format(self.name))
        
        #if 1 record found
        elif (len(mylines)==1):
            print('\nStudent details which you selected to update\n')
            for element in mylines:
                li=element.split(',')
                print('Student_Name: {} \nID: {} \nDOB: {} \nSubject: {}' .format(li[0], li[1], li[2], li[3]))
            
            ch = int(input('\n1. To update Student name \n2. To update Date of Birth \n3. To update Subject \n'))
            
            #to update student name
            if ch == 1 :
                new_st_name=input('Enter new Student name :')
                for element in mylines:
                    li=element.split(',')
                li[0]=new_st_name
                my_string = ','.join(map(str, li))
                new_mylines=list(my_string)
                output = output + new_mylines
                
                f = open("students.txt", 'w')
                f.writelines(output)
                f.close()
                
                print('\nUpdated Student record details\n')
                print('Student_Name: {} \nID: {} \nDOB: {} \nSubject: {}' .format(li[0], li[1], li[2], li[3]))                         
            
            #to update student DOB
            elif ch == 2 :
                new_st_dob=input('Enter Date of Birth :')
                for element in mylines:
                    li=element.split(',')
                li[2]=new_st_dob
                my_string = ','.join(map(str, li))
                new_mylines=list(my_string)
                output = output + new_mylines
                
                f = open("students.txt", 'w')
                f.writelines(output)
                f.close()
                
                print('\nUpdated Student record details\n')
                print('Student_Name: {} \nID: {} \nDOB: {} \nSubject: {}' .format(li[0], li[1], li[2], li[3])) 
                
            #to update student Subject
            elif ch == 3 :
                new_st_sub=input('Enter new Subject :')
                for element in mylines:
                    li=element.split(',')
                li[3]=new_st_sub
                my_string = ','.join(map(str, li))
                new_mylines=list(my_string)
                output = output + new_mylines
                
                f = open("students.txt", 'w')
                f.writelines(output)
                f.close()
                
                myfile=open('students.txt', 'a+')
                myfile.write('\n' )
                myfile.close()
                
                print('\nUpdated Student record details\n')
                print('Student_Name: {} \nID: {} \nDOB: {} \nSubject: {}' .format(li[0], li[1], li[2], li[3]))                 
                           
        #if more than 1 record found
        else :
            print('\n{} records found for {}\n' .format(len(mylines), self.name))
            for element in mylines:
                li=element.split(',')
                print('Student_Name: {} \nID: {} \nDOB: {} \nSubject: {}' .format(li[0], li[1], li[2], li[3]))
            check_id=int(input('\nPlease enter the specific Student ID to update the student {} :' .format(self.name)))
            
            #to update specific student record
            for element in mylines:
                if (self.name+','+str(check_id)+',') not in element:
                    update_line.append(element)
                else:
                    new_lines.append(element)
            output = output + update_line

            ch = int(input('\n1. To update Student name \n2. To update Date of Birth \n3. To update Subject \n'))
            
            #to update student name
            if ch == 1 :
                new_st_name=input('Enter new Student name :')
                for element in new_lines:
                    li=element.split(',')
                li[0]=new_st_name
                my_string = ','.join(map(str, li))
                new_mylines=list(my_string)
                output = output + new_mylines
                
                f = open("students.txt", 'w')
                f.writelines(output)
                f.close()
                
                print('\nUpdated Student record details\n')
                print('Student_Name: {} \nID: {} \nDOB: {} \nSubject: {}' .format(li[0], li[1], li[2], li[3]))                         
            
            #to update student DOB
            elif ch == 2 :
                new_st_dob=input('Enter Date of Birth :')
                for element in new_lines:
                    li=element.split(',')
                li[2]=new_st_dob
                my_string = ','.join(map(str, li))
                new_mylines=list(my_string)
                output = output + new_mylines
                #output= '\n'.join([output, new_mylines])
                
                f = open("students.txt", 'w')
                f.writelines(output)
                f.close()
                
                print('\nUpdated Student record details\n')
                print('Student_Name: {} \nID: {} \nDOB: {} \nSubject: {}' .format(li[0], li[1], li[2], li[3])) 
                
            #to update student Subject
            elif ch == 3 :
                new_st_sub=input('Enter new Subject :')
                for element in new_lines:
                    li=element.split(',')
                li[3]=new_st_sub
                my_string = ','.join(map(str, li))
                new_mylines=list(my_string)
                output = output + new_mylines
                
                f = open("students.txt", 'w')
                f.writelines(output)
                f.close()

                myfile=open('students.txt', 'a+')
                myfile.write('\n' )
                myfile.close()                
                
                print('\nUpdated Student record details\n')
                print('Student_Name: {} \nID: {} \nDOB: {} \nSubject: {}' .format(li[0], li[1], li[2], li[3]))                 

        
def menu():
    print('***********************************')
    print('Welcome to School Managemnet system')
    print('***********************************')
        
    while True:
        print('\n\nSelect the options\n')
        print('1. To select Students details \n2. To select Teacher deatils \n3. To exit \n')
        #a = int(input('1. To select Students details \n2. To select Teacher deatils \n'))
        a=int(input())

        #for Students
        if a == 1:
            print('\n\n1. To Add new Student deatils \n2. To View Student deatils \n3. To Delete Student deatils \n4. To Update Student deatils')
            choice=int(input())
            if choice==1:
                try:
                    num=int(input("Please enter the number of Student records to be added :"))
                except:
                    print('\nNext time Please enter the number of Student records to be added ')
                else:
                    for i in range(1, num+1):
                        student_name=input("Please enter Student Name :")
                        ob = Student(student_name)
                        ob.accept()


            elif choice==2:
        #         try:
        #             num=int(input("Please enter the number of Student records to be view :"))
        #         except:
        #             print('\nNext time Please enter the number of Student records to be view')
        #         else:
        #             for i in range(1, num+1):
                        student_name=input("Please enter Student Name :")
                        ob = Student(student_name)
                        ob.view()        


            elif choice==3:
                student_name=input("Please enter Student Name :")
                ob = Student(student_name)
                ob.remove()

            elif choice==4:
                student_name=input("Please enter Student Name :")
                ob = Student(student_name)
                ob.update()

        #for Teachers
        elif a ==2:
            print('select1')
            print('\n\n1. To Add new Teacher deatils \n2. To View Teacher deatils \n3. To Delete Teacher deatils \n4. To Update Teacher deatils')
            choice=int(input())
            if choice==1:
                try:
                    num=int(input("Please enter the number of Teacher records to be added :"))
                except:
                    print('\nNext time Please enter the number of Teacher records to be added ')
                else:
                    for i in range(1, num+1):
                        teacher_name=input("Please enter Teacher Name :")
                        ob = Teacher(teacher_name)
                        ob.accept()


            elif choice==2:
        #         try:
        #             num=int(input("Please enter the number of Student records to be view :"))
        #         except:
        #             print('\nNext time Please enter the number of Student records to be view')
        #         else:
        #             for i in range(1, num+1):
                        teacher_name=input("Please enter Teacher Name :")
                        ob = Teacher(teacher_name)
                        ob.view()        


            elif choice==3:
                teacher_name=input("Please enter Teacher Name :")
                ob = Teacher(teacher_name)
                ob.remove()

            elif choice==4:
                teacher_name=input("Please enter Teacher Name :")
                ob = Teacher(teacher_name)
                ob.update()


        elif a==3:
            break
        else:
            print('Enter valid choice')
            
            
if __name__ == "__main__":
    menu()
# Out:
# ***********************************
# Welcome to School Managemnet system
# ***********************************
#
#
# Select the options
#
# 1. To select Students details
# 2. To select Teacher deatils
# 3. To exit
#
# 3
